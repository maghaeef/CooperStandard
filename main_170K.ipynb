# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Mohammad/CooperStandard')

# %%
# main_experiment.py
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from experiment_runner import ExperimentRunner

# %%
# Configuration parameters.
file_path = file_path = "/content/drive/MyDrive/Mohammad/CooperStandard/DataOn2025Jan08.xlsx"
sheet_names = ["NES170K07Line2", "NES170K07Line1"]
compound_name = "170K"
variables = [
    "batch_number", "MDRTorqueS1", "MDRTorqueS2",
    "mh", "ml", "TimeAtML", "TimeAtML_min", "ml_min",
    "start_time", "end_time", "t5"
]

# Instantiate the experiment runner.
experiment = ExperimentRunner(file_path, sheet_names, compound_name, variables)

# Run experiments for both scenarios.
results_no_aug = experiment.run_experiment(use_augmentation=False)
results_aug = experiment.run_experiment(use_augmentation=True)

# Build a results DataFrame.
rows = []
for scenario, result in [("No Augmentation", results_no_aug), ("Augmentation", results_aug)]:
    for dataset in ["train", "val", "test"]:
        dp_counts = result["datapoints"][dataset]
        perf = result["performance"][dataset]
        for region in ["low", "normal", "high"]:
            row = {
                "Scenario": scenario,
                "Dataset": dataset,
                "Region": region,
                "DataPoints": dp_counts.get(region, 0),
                "MSE": perf.get(region, {}).get("mse", None),
                "MAE": perf.get(region, {}).get("mae", None),
                "Accuracy": perf.get(region, {}).get("accuracy", None)
            }
            rows.append(row)

results_df = pd.DataFrame(rows)
results_df
#results_df.to_csv("experiment_results.csv", index=False)
# Out:
# Using original training data without augmentation.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# Augmenting training data for balancing...
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
#            Scenario Dataset  Region  DataPoints       MSE       MAE   Accuracy
# 0   No Augmentation   train     low         223  0.762190  0.800920   3.139013
# 1   No Augmentation   train  normal        4435  0.191000  0.350110  99.549042
# 2   No Augmentation   train    high         360  0.967684  0.897794   5.555556
# 3   No Augmentation     val     low          52  1.427055  0.972923   5.769231
# 4   No Augmentation     val  normal         945  0.208584  0.361976  99.365079
# 5   No Augmentation     val    high          78  1.034767  0.934892   2.564103
# 6   No Augmentation    test     low          34  0.775978  0.805660   5.882353
# 7   No Augmentation    test  normal         961  0.201105  0.360397  99.479709
# 8   No Augmentation    test    high          81  0.977461  0.901473   3.703704
# 9      Augmentation   train     low        4435  0.279657  0.395832  59.751973
# 10     Augmentation   train  normal        4435  0.412268  0.519038  80.653890
# 11     Augmentation   train    high        4435  0.356355  0.433358  54.160090
# 12     Augmentation     val     low          52  0.899723  0.623735  53.846154
# 13     Augmentation     val  normal         945  0.431738  0.528257  79.894180
# 14     Augmentation     val    high          78  0.534350  0.538057  47.435897
# 15     Augmentation    test     low          34  0.442030  0.430161  64.705882
# 16     Augmentation    test  normal         961  0.436306  0.531829  79.604579
# 17     Augmentation    test    high          81  0.514506  0.542307  44.444444
